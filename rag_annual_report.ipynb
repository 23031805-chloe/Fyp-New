# %%
import docling_util

# %%
docling_util.process_documents_to_md("input", "no image annotation")
docling_util.process_markdown_folder('output_md') # process_markdown_folder always dump to 'outputs' folder
# Out:
# .pdf files found:
#   - Introduction-to-Education-1701296386.pdf
#
# Total files to process: 1
# Processing documents:   0%|          | 0/1 [00:00<?, ?it/s]2025-11-19 15:29:36,327 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-11-19 15:29:42,207 - INFO - Going to convert document batch...
# 2025-11-19 15:29:42,216 - INFO - Initializing pipeline for StandardPdfPipeline with options hash 6b7246e1a8b1b385a6fb533fe769cb74
# 2025-11-19 15:29:42,998 - INFO - Loading plugin 'docling_defaults'
# 2025-11-19 15:29:43,045 - WARNING - The plugin langchain_docling will not be loaded because Docling is being executed with allow_external_plugins=false.
# 2025-11-19 15:29:43,046 - INFO - Registered ocr engines: ['easyocr', 'ocrmac', 'rapidocr', 'tesserocr', 'tesseract']
# 2025-11-19 15:29:44,375 - INFO - Accelerator device: 'cpu'
# 2025-11-19 15:29:46,549 - INFO - Accelerator device: 'cpu'
# 2025-11-19 15:29:48,379 - INFO - Accelerator device: 'cpu'
# 2025-11-19 15:29:49,059 - INFO - Loading plugin 'docling_defaults'
# 2025-11-19 15:29:49,070 - WARNING - The plugin langchain_docling will not be loaded because Docling is being executed with allow_external_plugins=false.
# 2025-11-19 15:29:49,071 - INFO - Registered picture descriptions: ['vlm', 'api']
# 2025-11-19 15:29:49,075 - INFO - Processing document Introduction-to-Education-1701296386.pdf
# c:\Users\23031805\Downloads\docling_demo\.venv\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# c:\Users\23031805\Downloads\docling_demo\.venv\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# c:\Users\23031805\Downloads\docling_demo\.venv\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# c:\Users\23031805\Downloads\docling_demo\.venv\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# c:\Users\23031805\Downloads\docling_demo\.venv\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# c:\Users\23031805\Downloads\docling_demo\.venv\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# c:\Users\23031805\Downloads\docling_demo\.venv\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# c:\Users\23031805\Downloads\docling_demo\.venv\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# c:\Users\23031805\Downloads\docling_demo\.venv\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# c:\Users\23031805\Downloads\docling_demo\.venv\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# c:\Users\23031805\Downloads\docling_demo\.venv\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# c:\Users\23031805\Downloads\docling_demo\.venv\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# 2025-11-19 15:34:36,773 - INFO - Finished converting document Introduction-to-Education-1701296386.pdf in 300.48 sec.
# Processing documents: 100%|██████████| 1/1 [05:01<00:00, 301.13s/it]
# ✓ Processed: input\Introduction-to-Education-1701296386.pdf
# Processing markdown files in folder: output_md
#
# Processing md file: output_md\annual-report-sats-ltd-2023-2024_p8_only.md
# Analyzing image filename: output_md\output_md\annual-report-sats-ltd-2023-2024_p8_only_artifacts\image_000000_d8bc9028ada8322e6b0ec8f6e732f3a6f7c40b186acd1253214510a184244513.png
# Analyzing image filename: output_md\output_md\annual-report-sats-ltd-2023-2024_p8_only_artifacts\image_000001_2f921325119f8baefb49fa2b677a39fba18e2fecbd5a4474be8950fcbee628c7.png
# Successfully updated 'output_md\annual-report-sats-ltd-2023-2024_p8_only.md' with formatted image descriptions.
#
# Processing md file: output_md\FoodRegulationsSALE-OF-FOOD-ACT.md
# Successfully updated 'output_md\FoodRegulationsSALE-OF-FOOD-ACT.md' with formatted image descriptions.
#
# Processing md file: output_md\Introduction-to-Education-1701296386.md
# Analyzing image filename: output_md\output_md\Introduction-to-Education-1701296386_artifacts\image_000000_7e934fd0c3d43a6a87cc8e511b9040da16f887661abe87fddd638291f321e613.png
# Analyzing image filename: output_md\output_md\Introduction-to-Education-1701296386_artifacts\image_000001_5636b16be0c90ad7df5d96703dac83ba0770d984ae4ed0c8436380060afc83a4.png
# Analyzing image filename: output_md\output_md\Introduction-to-Education-1701296386_artifacts\image_000002_d6d995cd5bf1c39c5eaddc32cc27b3748a48a5c497fbe0047d6126b773475a6f.png
# Analyzing image filename: output_md\output_md\Introduction-to-Education-1701296386_artifacts\image_000003_602efed9b783c2a44c2d44bc47f111a1880e470a51f1c01a0b4b119fb8e5638a.png
# Analyzing image filename: output_md\output_md\Introduction-to-Education-1701296386_artifacts\image_000004_6c90f2adb78178053d26bf0b8203e785d1a3a8d9500193d05cc77c53cfb7efdb.png
# Analyzing image filename: output_md\output_md\Introduction-to-Education-1701296386_artifacts\image_000005_5d4b0396e97202e72ce283d8c15603f59496927ca2b9bd2599a8c9290b9db6f6.png
# Analyzing image filename: output_md\output_md\Introduction-to-Education-1701296386_artifacts\image_000006_329a7a4cd18abeaca0c36a5e6147cd7852656e583538a534ad45bf6e5129699a.png
# Analyzing image filename: output_md\output_md\Introduction-to-Education-1701296386_artifacts\image_000007_764468c41b9639cec0e84c8c9081e56fd2f5f14651151e641ace7341176d1a76.png
# Analyzing image filename: output_md\output_md\Introduction-to-Education-1701296386_artifacts\image_000008_81ee6b7520bb4230e0890b3a639a474cd640cad8fe5133616b9484f5f654e12a.png
# Analyzing image filename: output_md\output_md\Introduction-to-Education-1701296386_artifacts\image_000009_fef01ef891a552ae7b0d9c05647cdf8a231d3d0674752e68049ba99b3e48eedf.png
# Analyzing image filename: output_md\output_md\Introduction-to-Education-1701296386_artifacts\image_000010_355ef516916bfd3c0de7c3699ac42ea71e64b54b2fda69155a73a6edb98a1458.png
# Analyzing image filename: output_md\output_md\Introduction-to-Education-1701296386_artifacts\image_000011_fa17c7903c4e6a4375e4f81dc783ab65da4963a8a391ace18941be688f4f2c86.png
# Analyzing image filename: output_md\output_md\Introduction-to-Education-1701296386_artifacts\image_000012_3fdea97081b4d97fa7c76d5d747c986e96607125bb9c7f092201828bd7a588a7.png
# Analyzing image filename: output_md\output_md\Introduction-to-Education-1701296386_artifacts\image_000013_e40a88d19ad6fead70bfbc31c68190a587802224cb175f9de5581d6cb18f6ce6.png
# Analyzing image filename: output_md\output_md\Introduction-to-Education-1701296386_artifacts\image_000014_ff35af9a54dc766552b33d0045c79da5d18e30ad6e76b1bb946073fd8890b6d0.png
# An error occurred: Error analyzing image: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.0-flash
# Please retry in 53.375457351s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , retry_delay {
#   seconds: 53
# }
# ]

# %%
docling_util.create_chroma_vectordb(
    file_paths=[
        "output_md\\Introduction-to-Education-1701296386.md",
        "output_md\\FoodRegulationsSALE-OF-FOOD-ACT.md",
        "output_md\\annual-report-sats-ltd-2023-2024_p8_only.md"
    ]
)
# Out:
# 2025-11-19 15:36:05,128 - INFO - detected formats: [<InputFormat.MD: 'md'>]
# 2025-11-19 15:36:05,134 - INFO - Going to convert document batch...
# 2025-11-19 15:36:05,135 - INFO - Initializing pipeline for SimplePipeline with options hash 4cc01982ae99b46a2a63fcda46c47c35
# 2025-11-19 15:36:05,136 - INFO - Processing document Introduction-to-Education-1701296386.md
# 2025-11-19 15:36:16,053 - INFO - Finished converting document Introduction-to-Education-1701296386.md in 10.92 sec.
# 2025-11-19 15:36:17,361 - INFO - detected formats: [<InputFormat.MD: 'md'>]
# 2025-11-19 15:36:17,371 - INFO - Going to convert document batch...
# 2025-11-19 15:36:17,373 - INFO - Processing document FoodRegulationsSALE-OF-FOOD-ACT.md
# 2025-11-19 15:37:04,689 - INFO - Finished converting document FoodRegulationsSALE-OF-FOOD-ACT.md in 47.36 sec.
# Token indices sequence length is longer than the specified maximum sequence length for this model (917 > 512). Running this sequence through the model will result in indexing errors
# 2025-11-19 15:37:09,847 - INFO - detected formats: [<InputFormat.MD: 'md'>]
# 2025-11-19 15:37:09,848 - INFO - Going to convert document batch...
# 2025-11-19 15:37:09,849 - INFO - Processing document annual-report-sats-ltd-2023-2024_p8_only.md
# 2025-11-19 15:37:10,093 - INFO - Finished converting document annual-report-sats-ltd-2023-2024_p8_only.md in 0.27 sec.
# c:\Users\23031805\Downloads\docling_demo\docling_util.py:263: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name=model_name)
# 2025-11-19 15:37:10,478 - INFO - Use pytorch device_name: cpu
# 2025-11-19 15:37:10,479 - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# 2025-11-19 15:37:14,018 - INFO - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# Vectorstore saved permanently to: c:\Users\23031805\Downloads\docling_demo\chroma_db

# %%
import query_util
import os
print(os.environ.get("WATSONX_APIKEY"))
qa_chain_from_path = query_util.setup_qa_chain(local_vector_store_path="./chroma_db")
# Out:
# cuKVElisHQY5N671d4eLgEXoXd7nTInE3k5EpIqzSOTK
# 2025-11-19 15:38:31,191 - INFO - Client successfully initialized
# 2025-11-19 15:38:33,425 - INFO - HTTP Request: GET https://us-south.ml.cloud.ibm.com/ml/v1/foundation_model_specs?version=2025-10-24&project_id=e1c25433-111f-4f37-88b2-eda78598d018&filters=%21lifecycle_withdrawn&limit=200 "HTTP/1.1 200 OK"
# 2025-11-19 15:38:33,469 - INFO - Successfully finished Get available foundation models for url: 'https://us-south.ml.cloud.ibm.com/ml/v1/foundation_model_specs?version=2025-10-24&project_id=e1c25433-111f-4f37-88b2-eda78598d018&filters=%21lifecycle_withdrawn&limit=200'
# 2025-11-19 15:38:33,506 - INFO - Use pytorch device_name: cpu
# 2025-11-19 15:38:33,506 - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# Loading vector store from local path: ./chroma_db

# %%
print (query_util.ask_question(qa_chain_from_path, "what is the symbol of Singapore airlines?"))
# Out:
# c:\Users\23031805\Downloads\docling_demo\query_util.py:101: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = qa_chain({"query": question})
# 2025-11-19 15:38:42,371 - INFO - HTTP Request: POST https://us-south.ml.cloud.ibm.com/ml/v1/text/generation?version=2025-10-24 "HTTP/1.1 200 OK"
# 2025-11-19 15:38:42,393 - INFO - Successfully finished generate for url: 'https://us-south.ml.cloud.ibm.com/ml/v1/text/generation?version=2025-10-24'
# {'answer': '\nThe symbol of Singapore Airlines is a stylized golden bird emblem resembling a seagull in flight, positioned above the words "SINGAPORE AIRLINES" in a dark blue, slightly italicized sans-serif font, all set against a light blue background.', 'sources': ['output_md\\annual-report-sats-ltd-2023-2024_p8_only.md', 'output_md\\annual-report-sats-ltd-2023-2024_p8_only.md', 'output_md\\annual-report-sats-ltd-2023-2024_p8_only.md', 'output_md\\annual-report-sats-ltd-2023-2024_p8_only.md'], 'confidence': 4}

# %%
print (query_util.ask_question(qa_chain_from_path, "General purpose food additives"))
# Out:
# 2025-11-19 15:38:53,012 - INFO - HTTP Request: POST https://us-south.ml.cloud.ibm.com/ml/v1/text/generation?version=2025-10-24 "HTTP/1.1 200 OK"
# 2025-11-19 15:38:53,016 - INFO - Successfully finished generate for url: 'https://us-south.ml.cloud.ibm.com/ml/v1/text/generation?version=2025-10-24'
# {'answer': ' General purpose food additives are substances used during the processing or packaging of foods, including processing aids. They must be listed in the Eighth Schedule or permitted for use under this regulation. No one can import, sell, advertise, manufacture, consign, or deliver food containing any permitted general purpose food additive unless the food is sound and fit for human consumption. The list of permitted general purpose food additives includes Acetic acid, Acetone, Adipic acid, Ammonium bicarbonate, Ammonium carbonate, Ammonium hydroxide, Ammonium phosphate (mono- and di-basic), Ammonium sulphate, Aspartame, Beeswax, Calcium carbonate, Calcium chloride, Calcium citrate, Calcium gluconate, and Calcium hydroxide.', 'sources': ['output_md\\FoodRegulationsSALE-OF-FOOD-ACT.md', 'output_md\\FoodRegulationsSALE-OF-FOOD-ACT.md', 'output_md\\FoodRegulationsSALE-OF-FOOD-ACT.md', 'output_md\\FoodRegulationsSALE-OF-FOOD-ACT.md'], 'confidence': 4}

# %%
print (query_util.ask_question(qa_chain_from_path, "What is the total numnber of passengers carried by Scoot and Singapore Airlines combined"))
# Out:
# 2025-11-19 15:38:58,080 - INFO - HTTP Request: POST https://us-south.ml.cloud.ibm.com/ml/v1/text/generation?version=2025-10-24 "HTTP/1.1 200 OK"
# 2025-11-19 15:38:58,086 - INFO - Successfully finished generate for url: 'https://us-south.ml.cloud.ibm.com/ml/v1/text/generation?version=2025-10-24'
# {'answer': '36,443,231\n\nExplanation: To find the total number of passengers carried by Scoot and Singapore Airlines combined, we need to add the passengers carried by each airline separately. According to the context, Singapore Airlines carried 23,740,733 passengers and Scoot carried 118 passengers in FY2023/24. Therefore, the total number of passengers carried by both airlines combined is 23,740,733 + 118 = 36,443,231.', 'sources': ['output_md\\annual-report-sats-ltd-2023-2024_p8_only.md', 'output_md\\annual-report-sats-ltd-2023-2024_p8_only.md', 'output_md\\annual-report-sats-ltd-2023-2024_p8_only.md', 'output_md\\annual-report-sats-ltd-2023-2024_p8_only.md'], 'confidence': 4}

# %%
print (query_util.ask_question(qa_chain_from_path, "Why is there difference between the logos of Scoot and Singapore Airlines?"))
# Out:
# 2025-11-19 15:39:01,972 - INFO - HTTP Request: POST https://us-south.ml.cloud.ibm.com/ml/v1/text/generation?version=2025-10-24 "HTTP/1.1 200 OK"
# 2025-11-19 15:39:01,976 - INFO - Successfully finished generate for url: 'https://us-south.ml.cloud.ibm.com/ml/v1/text/generation?version=2025-10-24'
# {'answer': " The logos of Scoot and Singapore Airlines differ significantly due to their distinct brand identities and target markets. Scoot's logo features a simple, bold, black font within a bright yellow circle, emphasizing a playful and youthful image. In contrast, Singapore Airlines' logo incorporates a more elaborate, stylized golden bird emblem above its name, symbolizing elegance, movement, and a connection to aviation. These differences reflect each airline's unique positioning and appeal to different customer segments.", 'sources': ['output_md\\annual-report-sats-ltd-2023-2024_p8_only.md', 'output_md\\annual-report-sats-ltd-2023-2024_p8_only.md', 'output_md\\annual-report-sats-ltd-2023-2024_p8_only.md', 'output_md\\annual-report-sats-ltd-2023-2024_p8_only.md'], 'confidence': 4}

# %%
print (query_util.ask_question(qa_chain_from_path, "Compare the performance of the Cathay Pacific and Singapore Airlines"))
# Out:
# 2025-11-19 15:39:05,888 - INFO - HTTP Request: POST https://us-south.ml.cloud.ibm.com/ml/v1/text/generation?version=2025-10-24 "HTTP/1.1 200 OK"
# 2025-11-19 15:39:05,891 - INFO - Successfully finished generate for url: 'https://us-south.ml.cloud.ibm.com/ml/v1/text/generation?version=2025-10-24'
# {'answer': '\nThe provided context does not contain specific figures or data comparing the performance of Cathay Pacific and Singapore Airlines. Therefore, I cannot provide a direct comparison based on the given information.', 'sources': ['output_md\\annual-report-sats-ltd-2023-2024_p8_only.md', 'output_md\\annual-report-sats-ltd-2023-2024_p8_only.md', 'output_md\\annual-report-sats-ltd-2023-2024_p8_only.md', 'output_md\\annual-report-sats-ltd-2023-2024_p8_only.md'], 'confidence': 4}

# %%
print(query_util.ask_question(qa_chain_from_path, "What is discussed in the Introduction to Education document?"))
# Out:
# 2025-11-19 15:39:09,737 - INFO - HTTP Request: POST https://us-south.ml.cloud.ibm.com/ml/v1/text/generation?version=2025-10-24 "HTTP/1.1 200 OK"
# 2025-11-19 15:39:09,740 - INFO - Successfully finished generate for url: 'https://us-south.ml.cloud.ibm.com/ml/v1/text/generation?version=2025-10-24'
# {'answer': " The Introduction to Education document discusses various aspects related to education, including the reasons for teaching, the purpose of school, characteristics of today's students, impacts of social issues on students, subjects taught, qualities of an effective teacher, creation of a positive classroom environment, ethical and legal issues in schools, educational philosophies, prioritization between excellence and equity, and expectations for new teachers. It is based on the textbook 'Education 2010 - Introduction to Education' by Brenda Alward.", 'sources': ['output_md\\Introduction-to-Education-1701296386.md', 'output_md\\Introduction-to-Education-1701296386.md', 'output_md\\Introduction-to-Education-1701296386.md', 'output_md\\Introduction-to-Education-1701296386.md'], 'confidence': 4}

# %%
print(query_util.ask_question(qa_chain_from_path, "What is the purpose of education?"))
# Out:
# 2025-11-19 15:44:50,759 - INFO - HTTP Request: POST https://us-south.ml.cloud.ibm.com/ml/v1/text/generation?version=2025-10-24 "HTTP/1.1 200 OK"
# 2025-11-19 15:44:50,762 - INFO - Successfully finished generate for url: 'https://us-south.ml.cloud.ibm.com/ml/v1/text/generation?version=2025-10-24'
# {'answer': " The purpose of education is multifaceted. On one hand, it serves as a means to provide students with knowledge and expand their minds, allowing them to be exposed to various ideas and concepts. This can lead to personal fulfillment. On the other hand, education aims to equip individuals with the necessary skills to secure employment and contribute economically to society. This includes fundamental skills such as reading, writing, and arithmetic, as well as vocational training for those who may not excel in traditional academic settings. Ultimately, education is a lifelong process of learning and growth, as described by John Dewey, rather than merely a preparation for future living. However, it's crucial to distinguish between education and schooling, as the latter can sometimes resemble an institution focused on drilling knowledge into learners according to a predetermined plan, potentially treating them as objects.", 'sources': ['output_md\\Introduction-to-Education-1701296386.md', 'output_md\\Introduction-to-Education-1701296386.md', 'output_md\\Introduction-to-Education-1701296386.md', 'output_md\\Introduction-to-Education-1701296386.md'], 'confidence': 4}

# %%
print(query_util.ask_question(qa_chain_from_path, "List the five key principles mentioned in the introduction."))
# Out:
# 2025-11-19 15:47:32,617 - INFO - HTTP Request: POST https://us-south.ml.cloud.ibm.com/ml/v1/text/generation?version=2025-10-24 "HTTP/1.1 200 OK"
# 2025-11-19 15:47:32,622 - INFO - Successfully finished generate for url: 'https://us-south.ml.cloud.ibm.com/ml/v1/text/generation?version=2025-10-24'
# {'answer': " The five key principles mentioned in the introduction are:\n\n1. Teachers instruct students according to the standards set by the hierarchy.\n2. Establishing classroom rules involves selecting tasks or activities at an appropriate level of difficulty for students, providing a moderate level of structure or clarity, and keeping alert to the flow and interplay of behaviors for the class as a whole and for individuals within it.\n3. Preparing instruction involves planning lessons that align with the school curriculum and considering the varying abilities of students.\n4. New teachers may face obstacles when planning lessons due to a lack of experience and knowledge about what lessons will look like over the course of a year.\n5. To address these challenges, new teachers can refer to resources such as the blog 'Countdown to Your First Year, What are Students Supposed to Learn?' for guidance.", 'sources': ['output_md\\Introduction-to-Education-1701296386.md', 'output_md\\Introduction-to-Education-1701296386.md', 'output_md\\Introduction-to-Education-1701296386.md', 'output_md\\Introduction-to-Education-1701296386.md'], 'confidence': 4}

# %%
print(query_util.ask_question(qa_chain_from_path, "Summarise the role of teachers."))
# Out:
# 2025-11-19 15:46:50,298 - INFO - HTTP Request: POST https://us-south.ml.cloud.ibm.com/ml/v1/text/generation?version=2025-10-24 "HTTP/1.1 200 OK"
# 2025-11-19 15:46:50,303 - INFO - Successfully finished generate for url: 'https://us-south.ml.cloud.ibm.com/ml/v1/text/generation?version=2025-10-24'
# {'answer': ' Teachers play a multifaceted role in education, going beyond merely imparting information. They are individuals who yearn to help children learn, observe their growth, and create a positive impact on the world. Despite often receiving low to fair compensation, teachers find immense satisfaction in nurturing young minds and igniting their passion for knowledge. Instructing between twenty and thirty students with varying learning needs, teachers employ various methods to ensure student engagement, aligning their teaching practices with established educational standards.', 'sources': ['output_md\\Introduction-to-Education-1701296386.md', 'output_md\\Introduction-to-Education-1701296386.md', 'output_md\\Introduction-to-Education-1701296386.md', 'output_md\\Introduction-to-Education-1701296386.md'], 'confidence': 4}

# %%
print(query_util.ask_question(qa_chain_from_path, ""))
